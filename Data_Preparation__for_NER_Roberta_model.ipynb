# %% [markdown]
# <a href="https://colab.research.google.com/github/Zain1796/Lucky-Cement-AI-System/blob/main/Data_Preparation__for_NER_Roberta_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# while preparing data for NER in urdu text and train roberta large model.
#
#
# *   Annotating brand name with other to balance data.

# %% [markdown]
# Combining all_ner_1 and all_ner_2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
import os

def combine_jsonl_files(file1, file2, output_file):
    with open(file1, 'r', encoding='utf-8') as f1, open(file2, 'r', encoding='utf-8') as f2:
        # Read lines from both files
        data1 = f1.readlines()
        data2 = f2.readlines()

    # Combine the data
    combined_data = data1 + data2

    # Write the combined data to the output file
    with open(output_file, 'w', encoding='utf-8') as output_f:
        output_f.writelines(combined_data)

# Replace 'file1.jsonl', 'file2.jsonl', and 'output_combined.jsonl' with your actual file names
file1 = '/content/drive/MyDrive/Joyn_NewDataNLP/NER/all_NER_iter1.jsonl'
file2 = '/content/drive/MyDrive/Joyn_NewDataNLP/NER/ALL_NER_ITR2.jsonl'
file3 = '/content/drive/MyDrive/Joyn_NewDataNLP/NER/Combined_NER_ITR1&2.jsonl'
combine_jsonl_files(file1, file2, file3)

# %% [markdown]
# Specific brand_data

# %%
import json

file_path = r"/content/drive/MyDrive/Joyn_NewDataNLP/NER/Combined_NER_ITR1&2.jsonl"
user_specified_value = "Lucky_Margin"  # Change this value to the one you want to filter by

# Reading  file
with open(file_path, 'r', encoding='utf-8') as file:
    # Read lines from the file
    lines = file.readlines()

    # List to store filtered dictionaries
    filtered_data = []

    # Iterate through each line and load each line as a JSON object
    for line in lines:
        # Load JSON from the current line
        data = json.loads(line)

        # Check if the 'label' key contains the user-specified value
        labels = [label[2] for label in data.get('label', [])]
        if user_specified_value in labels:
            # If the value is found, add the dictionary to the filtered data
            filtered_data.append(data)

# Printing or save the filtered data
# for i, data in enumerate(filtered_data):
#     print(f"Filtered Dictionary {i + 1}: {data}")

# # saving the filtered data to a new file
# output_file_path = r"D:\joyn\filtered_data.json"
# with open(output_file_path, 'w', encoding='utf-8') as output_file:
#     json.dump(filtered_data, output_file, ensure_ascii=False, indent=2)

print(f"\nNumber of dictionaries in the input file: {len(lines)}")
print(f"Number of dictionaries in the filtered data: {len(filtered_data)}")
#print(f"Filtered data saved to {output_file_path}")
# Out:
# Number of dictionaries in the input file: 1031
# Number of dictionaries in the filtered data: 14

# %% [markdown]
# Falcon 50 to Power   ,20 to PakLad ,50 to Thatta, 20 to DG

# %%
import json
import re
import codecs
import random


def replace_text(text, old_word, new_word):
    return text.replace(old_word, new_word)


def replace_label(label, old_brand, new_brand):
    return [[item[0], item[1], item[2].replace(old_brand, new_brand)] for item in label]

new_word = 'پاور '#input('یہاں جو لفظ آپ تبدیل کرنا چاہتے ہیں  :')
old_word = 'لکی' #input('یہاں جس  لفظ سے آپ تبدیل کرنا چاہتے ہیں  :')
old_brand = "Lucky"#input('inter old brand  :')
new_brand = "Power"#input('inter new brand  :')


LM10tP = []
dicts = random.sample(filtered_data,10)
for dic in dicts:
  if old_word in dic['text']:
    dic['text'] = replace_text(dic['text'], old_word, new_word)
    dic['label'] = replace_label(dic['label'], old_brand, new_brand)
    LM10tP.append(dic)
with open('LM10tP.jsonl', 'w') as f:
    json.dump(LM10tP, f, ensure_ascii=False)
print(len(LM10tP))
# Out:
# 10

# %%
import os
import json

# Specify the directory containing the JSONL files
directory = '/content/'

# Specify the output file name
output_file_name = '/content/wrka_dng.jsonl'

# Function to combine JSONL files
def combine_jsonl_files(directory, output_file):
    combined_data = []

    # Iterate over files in the specified directory
    for filename in os.listdir(directory):
        if filename.endswith(".jsonl"):
            file_path = os.path.join(directory, filename)
            with open(file_path, 'r', encoding='utf-8') as file:
                # Read lines from the current file and append to combined_data
                combined_data.extend(file.readlines())
    print(len(combined_data))

    # Write the combined data to the output file
    with open(output_file, 'w', encoding='utf-8') as output_f:
        output_f.writelines(combined_data)

# Combine JSONL files in the specified directory
combine_jsonl_files(directory, output_file_name)
# Out:
# 5

# %%
import json
import os

def combine_jsonl_files(file1, file2, output_file):
    with open(file1, 'r', encoding='utf-8') as f1, open(file2, 'r', encoding='utf-8') as f2:
        # Read lines from both files
        data1 = f1.readlines()
        data2 = f2.readlines()

    # Combine the data
    combined_data = data1 + data2

    # Write the combined data to the output file
    with open(output_file, 'w', encoding='utf-8') as output_f:
        output_f.writelines(combined_data)

# Replace 'file1.jsonl', 'file2.jsonl', and 'output_combined.jsonl' with your actual file names
file1 = '/content/output_combined.jsonl'
file3 = '/content/drive/MyDrive/Joyn_NewDataNLP/NER/ALL_Argumented_NER_ITR1&2.jsonl'
file2 = '/content/drive/MyDrive/Joyn_NewDataNLP/NER/Combined_NER_ITR1&2.jsonl'
combine_jsonl_files(file1, file2, file3)

# %%
print(len(combined_data))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-7a1686a5db11> in <cell line: 1>()
# ----> 1 print(len(combined_data))
#
# NameError: name 'combined_data' is not defined

# %%
with open(file3, 'r', encoding='utf-8') as f1:
  ata1 = f1.readlines()
  print(len(ata1))
# Out:
# 1031

# %%
import json
import glob

# Specify the path to your JSONL files
files_path = '/content/*.jsonl'

# List to store all dictionaries from all files
all_data = []

# Read and combine JSONL files
for file in glob.glob(files_path):
    with open(file, 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for line in lines:
          data = json.loads(line)
          all_data.extend(data)  # Use extend to add all items to the list

# Save the combined list to a new JSONL file (optional)
#output_file_path = '/content/drive/MyDrive/path/to/output_file.jsonl'
with open('pura_data.jsonl', 'w', encoding='utf-8') as output_file:
    for data in all_data:
        json_line = json.dumps(data, ensure_ascii=False)
        output_file.write(json_line + '\n')

# Print the combined list (optional)
print(len(all_data))
print(all_data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-100-d615693c3191> in <cell line: 11>()
#      13         lines = f.readlines()
#      14         for line in lines:
# ---> 15           data = json.loads(line)
#      16           all_data.extend(data)  # Use extend to add all items to the list
#      17
#
# /usr/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /usr/lib/python3.10/json/decoder.py in decode(self, s, _w)
#     338         end = _w(s, end).end()
#     339         if end != len(s):
# ...

# %%
import json

# Specify the input directory and output file
input_directory = '/content/'
output_file = '/content/wrka_dng.jsonl'

# List to store all the JSON objects
all_data = []

# Iterate over files in the specified directory
for filename in os.listdir(input_directory):
    if filename.endswith(".jsonl"):
        file_path = os.path.join(input_directory, filename)
        with open(file_path, 'r', encoding='utf-8') as f:
            lines = f.readlines()
            for line in lines:
                try:
                    # Parse each line as a JSON object
                    data = json.loads(line)
                    all_data.append(data)
                except json.JSONDecodeError as e:
                    print(f"Error decoding JSON in file {filename}: {e}")

# Write the combined data to the output file
with open(output_file, 'w', encoding='utf-8') as output_f:
    for data in all_data:
        # Write each JSON object on a new line
        output_f.write(json.dumps(data) + '\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-a6bba0a7a369> in <cell line: 11>()
#       9
#      10 # Iterate over files in the specified directory
# ---> 11 for filename in os.listdir(input_directory):
#      12     if filename.endswith(".jsonl"):
#      13         file_path = os.path.join(input_directory, filename)
#
# NameError: name 'os' is not defined

# %%
print(all_data)
# Out:
# [[{'id': 2547, 'text': 'لکی کا کیا ریٹ آرہا ہے ابھی آپکو لکی کا مجھے نہیں پتا عرفان بھی کو پتا ہے عرفان کو پتا ہے ساری باتیں ہمنے صرف بیچنے کا اچھا لکی کتنے کا بیچ رہے ہو ہم 1130 کا بیچتے 1130 1120 صحیح چلیں اچھا ہے پھر اور پاک لینڈ 1100 1100 اور یہ چاولہ کا ہے نہیں نہیں پھر یہ بھی نیچے وہ اپنا حاجی حاجی نہیں ہے حاجی ارتضیٰ دے رہے ہیں تو یہ کتنے کا بیچ رہے ہیں   یہ 1100 کا ہے اور پاک لینڈ  پیرا ہوا ہے پیچھے پاک لینڈ  1130 کا ہے تو زیادہ آپکا کونسا چل رہا ہے زیادہ ہمارا فالکن چلتا ہے یا یہ پاک لینڈ چلتا ہے آج سمبھال پاک لینڈ چل گیا ٹھیکیدار ٹھیکیدار اصل میں جو ٹھیکیدار وہ پاک لینڈ کو مانگتے ہیں پاک لینڈ کو پاک لینڈ کو اس لئے مانگتے ہیں نہ کے کچھ بچ جاتے ہیں. یاد نہیں رہا صحیح ہے ابھی میں آپکو چار پانچ لوگ نیکسٹ میں پھر انشاللہ آپکو ہاں ہاں فالکن کتنے کا ریٹیل ہو رہا ہے فالکن ہم 1150 کا دے رہے ہیں صحیح ہے پھر بھی فالکن زیادہ نکلتا ہے ہاں فالکن پھر بھی زیادہ نکلتا ہے صحیح ہے اصل میں لوگوں کے ذھن میں نام لگا ہوا ہے کے فالکن لے آو ہاں بس یہ ہے صحیح کہ رہے ہیں باقی سیمنٹ تو لکی بھی ووہی ہے
# ...

# %%
import json
import os

# Specify the input directory and output file
input_directory = '/content/'
output_file = '/content/output_combined.jsonl'

# List to store all dictionaries
all_data = []

# Iterate over files in the specified directory
for filename in os.listdir(input_directory):
    if filename.endswith(".jsonl"):
        file_path = os.path.join(input_directory, filename)
        with open(file_path, 'r', encoding='utf-8') as f:
            lines = f.readlines()
            for line in lines:
                try:
                    # Parse each line as a list of dictionaries
                    data_list = json.loads(line)

                    # Extend the list with dictionaries from the current line
                    all_data.extend(data_list)
                except json.JSONDecodeError as e:
                    print(f"Error decoding JSON in file {filename}: {e}")

# Write the combined list of dictionaries to the output file
with open(output_file, 'w', encoding='utf-8') as output_f:
    # Write the entire list as a single JSON array
    output_f.write(json.dumps(all_data))
print(len(all_data))
# Out:
# 403

# %%
import json
import os

def combine_jsonl_files(file1, file2, output_file):
    with open(file1, 'r', encoding='utf-8') as f1, open(file2, 'r', encoding='utf-8') as f2:
        # Read lines from both files
        data1 = f1.readlines()
        data2 = f2.readlines()

    # Combine the data
    combined_data = data1 + data2

    # Write the combined data to the output file
    with open(output_file, 'w', encoding='utf-8') as output_f:
        output_f.writelines(combined_data)
output_file= '/content/drive/MyDrive/Joyn_NewDataNLP/NER/Argumented_NER_iter1&2_2.2.jsonl'
list_file  = '/content/pura_data.jsonl'
dict_file = '/content/drive/MyDrive/Joyn_NewDataNLP/NER/Argumented_NER_iter1&2.jsonl'

combine_jsonl_files(dict_file, list_file, output_file)

# %%
with open('output_file','r') as f:
  data = f.readlines()
  print(len(data))
# Out:
# 63

# %%
import json
import os

def combine_jsonl_files(dict_file, list_file, output_file):
    # Read dictionaries from the first file
    all_dicts = []
    with open(dict_file, 'r', encoding='utf-8') as f1:
        for line in f1:
            try:
                data_dict = json.loads(line)
                all_dicts.append(data_dict)
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON in file {dict_file}: {e}")

    # Read the list of dictionaries from the second file
    with open(list_file, 'r', encoding='utf-8') as f2:
        try:
            data_list = json.load(f2)
            # Extend the list of dictionaries with dictionaries from the second file
            all_dicts.extend(data_list)
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON in file {list_file}: {e}")
    print(len(all_dicts))
    Write the combined list of dictionaries to the output file
    with open(output_file, 'w', encoding='utf-8') as output_file:
      for data in all_dicts:
        json_line = json.dumps(data, ensure_ascii=False)
        output_file.write(json_line + '\n')
# Replace 'dict_file.jsonl', 'list_file.jsonl', and 'output_combined.jsonl'
# with your actual file names
# Replace 'file1.jsonl', 'file2.jsonl', and 'output_combined.jsonl' with your actual file names
output_file= '/content/drive/MyDrive/Joyn_NewDataNLP/NER/Argumented_NER_iter1&2_2.2.jsonl'
list_file  = '/content/pura_data.jsonl'
dict_file = '/content/drive/MyDrive/Joyn_NewDataNLP/NER/Argumented_NER_iter1&2.jsonl'

combine_jsonl_files(dict_file, list_file, output_file)
# Out:
# Error decoding JSON in file /content/pura_data.jsonl: Extra data: line 2 column 1 (char 2566)
# 1

# %%
with open('/content/output_file_path','r') as f:
  data = f.readlines()
  print(len(data))
# Out:
# 63

# %%
import json
import glob

# Specify the path to your JSONL files
files_path = '/content/*.jsonl'

# List to store all dictionaries from all files
all_data = []

# Read and combine JSONL files
for file in glob.glob(files_path):
    with open(file, 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for line in lines:
            data = json.loads(line)
            all_data.extend(data)  # Use extend to add all items to the list

# Save the combined list to a new JSONL file (optional)
#output_file_path = '/content/drive/MyDrive/path/to/output_file.jsonl'
with open('pura_data.jsonl', 'w', encoding='utf-8') as output_file:
    for data in all_data:
        json_line = json.dumps(data, ensure_ascii=False)
        output_file.write(json_line + '\n')

# Print the combined list (optional)
print(len(all_data))
print(all_data)
# Out:
# 64
# ...

# %%
import json

input_jsonl_file = '/content/drive/MyDrive/Joyn_NewDataNLP/NER/Argumented_NER_iter1&2_2.2.jsonl'

output_jsonl_file = 'output_file.jsonl'

# Read the input JSONL file
with open(input_jsonl_file, 'r', encoding='utf-8') as input_file:
    # Load the entire content of the file
    content = input_file.read()

# Parse the content as JSON
try:
    # Attempt to parse the entire content as a JSON object
    data = json.loads(content)

    # Initialize a list to store all dictionaries
    extracted_dicts = []

    # If it's a list of dictionaries, add them to the extracted list
    if isinstance(data, list) and all(isinstance(item, dict) for item in data):
        extracted_dicts.extend(data)

    # If there are dictionaries outside the list, add them as well
    if isinstance(data, dict):
        extracted_dicts.append(data)

except json.JSONDecodeError as e:
    print(f"Error decoding JSON: {e}")
    extracted_dicts = []

with open('pura_data.jsonl', 'w', encoding='utf-8') as output_file:
    for data in extracted_dicts:
        json_line = json.dumps(data, ensure_ascii=False)
        output_file.write(json_line + '\n')

#print(len(data))
print(len(extracted_dicts))
# Out:
# Error decoding JSON: Extra data: line 1 column 4522563 (char 4522562)
# 0

# %%
import json

# Specify the input and output file paths
input_file_path = '/content/drive/MyDrive/Joyn_NewDataNLP/NER/Argumented_NER_iter1&2_2.2.jsonl'
#output_file_path = '/path/to/output_file.jsonl'

dict_list = []

# Read the content of the input file line by line
with open(input_file_path, 'r', encoding='utf-8') as input_file:
    for line in input_file:
        try:
            # Attempt to load each line as a JSON object
            data = json.loads(line)

            # Check if the loaded data is a dictionary
            if isinstance(data, dict):
                dict_list.append(data)

        except json.JSONDecodeError as e:
            print(f"Error decoding JSON in line: {line}, Error: {e}")

# Write the dictionaries to the output file
with open('output_file_path', 'w', encoding='utf-8') as output_file:
    for dictionary in dict_list:
      json_line = json.dumps(data, ensure_ascii=False)
      output_file.write(json_line + '\n')
        #output_file.write(json.dumps(dictionary) + '\n')
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import json
file1_path = '/content/drive/MyDrive/Joyn_NewDataNLP/NER/Argumented_NER_iter1&2.jsonl'
out_path = '/content/drive/MyDrive/Joyn_NewDataNLP/NER/Argumented_NER_iter1&2_jsnofileformat.jsonl'
# Read data from the first file
with open(file1_path, 'r', encoding='utf-8') as file1:
    data1 = [json.loads(line) for line in file1.readlines()]

# Read data from the second file
# with open(file2_path, 'r', encoding='utf-8') as file2:
#     data2 = [json.loads(line) for line in file2.readlines()]

# Combine data from both files
# combined_data = data1 + data2
# print(len(combined_data))

# Write the combined data to the output file
with open(out_path, 'w', encoding='utf-8') as output_file:
    for data in data1:
        json_line = json.dumps(data, ensure_ascii=False)
        output_file.write(json_line + '\n')

# %%
# Write the combined data to the output file
with open('output_file1', 'w', encoding='utf-8') as output_file:
    for data in data1:
        print(data)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# Reading jsonl file

# %%
import jsonlines

file_path = '/content/drive/MyDrive/Joyn_NewDataNLP/NER/Argumented_NER_iter1&2.jsonl'
line_count = 0
with jsonlines.open(file_path) as reader:
    for _ in reader:
        line_count += 1
print(f'Total lines: {line_count}')
# Out:
# Total lines: 1

# %%
# !pip install jsonlines

# %%
# Out:
# 93

# %% [markdown]
# # **july argumentation**
